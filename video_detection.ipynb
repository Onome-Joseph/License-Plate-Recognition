# %% [markdown]
# # *License Plate Detection* for Vidoes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!pip install ultralytics

# %%
import os

from ultralytics import YOLO
import cv2

# Directory containing the video
VIDEOS_DIR = os.path.join('/content/drive/Othercomputers/My Laptop/NEW in Drive/license_folder/media')

# Input and output video paths
video_path = os.path.join(VIDEOS_DIR, 'sample_2.mp4')
video_path_out = f'{os.path.splitext(video_path)[0]}_out2.mp4'

# Open video file
cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()

if not ret:
    print("Failed to read the video. Check the video path.")
    cap.release()
    exit()

# Get video dimensions and initialize the VideoWriter
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

# Path to the trained model
model_path = os.path.join('/content/drive/Othercomputers/My Laptop/NEW in Drive/license_folder/license_trn.pt')
model = YOLO(model_path)

# Detection threshold
threshold = 0.2

# Process the video frame by frame
while ret:
    results = model(frame)[0]

    # Iterate over detected objects
    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            # Draw bounding box and label
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    # Write the processed frame to the output video
    out.write(frame)

    # Read the next frame
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# 0: 384x640 (no detections), 83.0ms
# Speed: 16.0ms preprocess, 83.0ms inference, 84.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.7ms
# Speed: 4.9ms preprocess, 9.7ms inference, 667.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.5ms
# Speed: 3.8ms preprocess, 9.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 license_plate, 9.4ms
# Speed: 3.7ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.5ms
# ...
